# %% [markdown]
# <font size = '8'>BDS 516 Homework 6: Credit Card Application Prediction</font>
#
# In this exercise, we will run an analysis on how to predict a bank's customer credit card application. The result of this analysis will be a machine learning model, resulting in a value of "Approved" or "Rejected", to predict all upcoming credit card application. We will try different models to predict customers' credit card application and use the best fitting model. The section of this analysis document is as follows: data manipulation, data visualization, data standardization, machine learning models, and conclusion.
#
# We start with importing all the necessary libraries to upload the data into the Python environment, clean them, and plot them into charts to better understand the data.

# %%
#import all necessary libraries for data cleaning
import pandas as pd #For working with dataframes
import numpy as np #For working with arrays, pandas is built on top of this
from pprint import pprint #For printing things nicely
import matplotlib.pyplot as plt #For plotting
import seaborn as sns

# %matplotlib inline

sns.set_style(style="whitegrid")

# %% [markdown]
# #Uploading the data and data manipulation
#
# Now, let's upload the data into the environment and take a look of the data that we will be working with.

# %%
crx_data = pd.read_csv("crx.data.csv",
                       index_col=False,
                       names=["Male", "Age", "Debt","Married", "BankCustomer","EducationLevel","Ethnicity","YearsEmployed",
                              "PriorDefault","Employed","CreditScore","DriversLicense","Citizen","ZipCode","Income","Approved"])
crx_data.head()
# Out:
#   Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    b  30.83  0.000       u            g              w         v
# 1    a  58.67  4.460       u            g              q         h
# 2    a  24.50  0.500       u            g              q         h
# 3    b  27.83  1.540       u            g              w         v
# 4    b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0   00202       0        +
# 1   00043     560        +
# 2   00280     824        +
# 3   00100       3        +
# 4   00120       0        +

# %% [markdown]
# It looks like we are working with both categorical and continous variables/columns from the dataset that we have uploaded. Let's take a look on what are the data types for each of the column.

# %%
#make a copy and take a look on each column data type
crx_data_clean = crx_data.copy()
crx_data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Male            690 non-null    object
#  1   Age             690 non-null    object
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    object
#  4   BankCustomer    690 non-null    object
#  5   EducationLevel  690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    object
#  9   Employed        690 non-null    object
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    object
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    object
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.4+ KB

# %% [markdown]
# From the result above, there are a total of 15 columns, including 1 dependend variable called "Approved." However, some of the columns seem to have a wrong data type, for example the variable age is considered as an object or string instead of float. Before we start changing all the columns data type to the correct one, we should find explore whether if there are missing values in any of our columns.

# %%
#check NA
print(crx_data_clean.isnull().sum())

#check value format for variable 'Age'
print(crx_data_clean.Age.value_counts())
# Out:
# Male              0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# EducationLevel    0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# Approved          0
# dtype: int64
# ?        12
# 22.67     9
# 20.42     7
# 18.83     6
# 24.50     6
#          ..
# 48.25     1
# 28.33     1
# 18.75     1
# 18.50     1
# 36.42     1
# Name: Age, Length: 350, dtype: int64

# %% [markdown]
# It seems Python does not identify any missing values (NaN) in any of the columns. However, if we take a look on the values of the 'Age' variable, we can see that there are 12 rows of data that contains '?' instead of NaN or age number. We will not be able to convert this variable data type into float right now since there is a '?' value which considered as a string. Before we convert the '?' into NaN, we should take a look whether the other columns have the same problem or not.

# %%
#there are 12 rows that contains '?' for age
#crx_data_clean.groupby(['Age'])['Age'].count()
crx_data_clean.Age.value_counts()
# Out:
# ?        12
# 22.67     9
# 20.42     7
# 18.83     6
# 24.50     6
#          ..
# 48.25     1
# 28.33     1
# 18.75     1
# 18.50     1
# 36.42     1
# Name: Age, Length: 350, dtype: int64

# %%
#the number of columns that contain '?'
crx_data_clean[crx_data_clean == '?'].count()
# Out:
# Male              12
# Age               12
# Debt               0
# Married            6
# BankCustomer       6
# EducationLevel     9
# Ethnicity          9
# YearsEmployed      0
# PriorDefault       0
# Employed           0
# CreditScore        0
# DriversLicense     0
# Citizen            0
# ZipCode           13
# Income             0
# Approved           0
# dtype: int64

# %% [markdown]
# It looks like our intuition is correct! There are multiple columns that contains '?' as one of the value. Now we have identified all the '?' values, we can first transform them into a NaN value before we fill them with other values in order to run our machine learning models.

# %%
cols = ["Male","Age","Married","BankCustomer","EducationLevel","Ethnicity","ZipCode"]
crx_data_clean[cols] = crx_data_clean[cols].replace({'?':np.nan, 0:np.nan})

# %% [markdown]
# Now once we have remove all the '?' values, we can start manipulating our data in order to fit them into machine learning models. First, we should transform all the supposedly continous variables, such as age and approved, into the correct data type, float.

# %%
#change the "Approved" column value, '+' into 1, '-' into 0, and "Male" column value to 1 & 0
crx_data_filtered['Approved'] = crx_data_filtered['Approved'].map({'+': 1, '-': 0})

# %%
#there are 12 rows that contains '?' for gender
crx_data_clean.groupby(['Male'])['Male'].count()
# Out:
# Male
# ?     12
# a    210
# b    468
# Name: Male, dtype: int64

# %%
#change '?' to 0 for column age
crx_data_filtered = crx_data_clean.copy()
crx_data_filtered.loc[ crx_data_filtered['Age'] == '?', 'Age'] = '0'

#and then double check if all '?' have changed to 0
crx_data_filtered.groupby(['Age'])['Age'].count()
# Out:
# Age
# 0        12
# 13.75     1
# 15.17     1
# 15.75     1
# 15.83     2
#          ..
# 71.58     1
# 73.42     1
# 74.83     1
# 76.75     1
# 80.25     1
# Name: Age, Length: 350, dtype: int64

# %%
#change the "Approved" column value, '+' into 1, '-' into 0, and "Male" column value to 1 & 0
crx_data_filtered['Approved'] = crx_data_filtered['Approved'].map({'+': 1, '-': 0})

# %%
#change the "Age" column from string to float
crx_data_filtered['Age'] = crx_data_filtered['Age'].astype(float)

#then double check if column 'Age' has changed to float
crx_data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Male            690 non-null    object
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    object
#  4   BankCustomer    690 non-null    object
#  5   EducationLevel  690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    object
#  9   Employed        690 non-null    object
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    object
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    object
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 86.4+ KB

# %%
crx_data_filtered_copy = crx_data_filtered.copy()

# %%
#group by age and count 
crx_data_filtered_copy.groupby(['Age'])['Age'].count()

#drop categorical columns from the df so we can run a regression analysis for column age
crx_data_filtered_copy = crx_data_filtered_copy.select_dtypes(exclude=['object'])

# %%
#fill missing values (age = 0) using linear regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

#create test and train df for age
test_age = crx_data_filtered_copy.loc[crx_data_filtered_copy['Age'] == 0]
train_age = crx_data_filtered_copy.loc[crx_data_filtered_copy['Age'] != 0]

#take the age column from the train_age df and assign it as the dependent variable (y)
y_age = train_age['Age']

#then drop the age column
train_age.drop('Age',axis=1,inplace=True)
#now you have dependent variable = y, and independent variables = the rest of the continous variables

#fit both independent and dependent variables to the lr model
lr.fit(train_age,y_age)
# Out:
# C:\Users\mangara\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# LinearRegression()

# %%
#drop age column from the test df
test_age.drop('Age',axis=1,inplace=True)

#predict test_age
pred = lr.predict(test_age)

#assign the predicted value to the test df
test_age['Age']= pred

#check test df to see the predicted value
print(test_age)
# Out:
#        Debt  YearsEmployed  CreditScore  Income  Approved        Age
# 83    3.500          3.000            0       0         0  31.906742
# 86    0.375          0.875            0       0         0  28.613093
# 92    5.000          8.500            0       0         0  39.117307
# 97    0.500          0.835            0       0         0  28.587763
# 254   0.625          0.250            0    2010         0  27.803782
# 286   1.500          0.000            2     105         0  27.939590
# 329   4.000          0.085            0       0         0  28.343459
# 445  11.250          0.000            0    5200         0  29.491904
# 450   3.000          7.000            0       1         0  36.833410
# 500   4.000          5.000            3    2279         1  35.161240
# 515  10.500          6.500            0       0         1  38.118182
# 608   0.040          4.250            0       0         0  32.787329
# C:\Users\mangara\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\mangara\AppData\Local\Temp/ipykernel_12992/4248156609.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_age['Age']= pred

# %%
#assign the age column back to the train df
train_age['Age'] = y_age
print(train_age)
# Out:
#        Debt  YearsEmployed  CreditScore  Income  Approved    Age
# 0     0.000           1.25            1       0         1  30.83
# 1     4.460           3.04            6     560         1  58.67
# 2     0.500           1.50            0     824         1  24.50
# 3     1.540           3.75            5       3         1  27.83
# 4     5.625           1.71            0       0         1  20.17
# ..      ...            ...          ...     ...       ...    ...
# 685  10.085           1.25            0       0         0  21.08
# 686   0.750           2.00            2     394         0  22.67
# 687  13.500           2.00            1       1         0  25.25
# 688   0.205           0.04            0     750         0  17.92
# 689   3.375           8.29            0       0         0  35.00
#
# [678 rows x 6 columns]
# C:\Users\mangara\AppData\Local\Temp/ipykernel_12992/4140776733.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_age['Age'] = y_age

# %%
#combine test and train df back
final_df = pd.concat([train_age, test_age])
final_df.head()
# Out:
#     Debt  YearsEmployed  CreditScore  Income  Approved    Age
# 0  0.000           1.25            1       0         1  30.83
# 1  4.460           3.04            6     560         1  58.67
# 2  0.500           1.50            0     824         1  24.50
# 3  1.540           3.75            5       3         1  27.83
# 4  5.625           1.71            0       0         1  20.17

# %%
#double check age
final_df.groupby(['Age'])['Age'].count()
# Out:
# Age
# 13.75    1
# 15.17    1
# 15.75    1
# 15.83    2
# 15.92    1
#         ..
# 71.58    1
# 73.42    1
# 74.83    1
# 76.75    1
# 80.25    1
# Name: Age, Length: 361, dtype: int64

# %%
print(final_df)
# Out:
#        Debt  YearsEmployed  CreditScore  Income  Approved        Age
# 0     0.000           1.25            1       0         1  30.830000
# 1     4.460           3.04            6     560         1  58.670000
# 2     0.500           1.50            0     824         1  24.500000
# 3     1.540           3.75            5       3         1  27.830000
# 4     5.625           1.71            0       0         1  20.170000
# ..      ...            ...          ...     ...       ...        ...
# 445  11.250           0.00            0    5200         0  29.491904
# 450   3.000           7.00            0       1         0  36.833410
# 500   4.000           5.00            3    2279         1  35.161240
# 515  10.500           6.50            0       0         1  38.118182
# 608   0.040           4.25            0       0         0  32.787329
#
# [690 rows x 6 columns]

# %%
#summary/descriptive statistics for all continuous variables
final_df.describe()
# Out:
#              Debt  YearsEmployed  CreditScore         Income    Approved  \
# count  690.000000     690.000000    690.00000     690.000000  690.000000
# mean     4.758725       2.223406      2.40000    1017.385507    0.444928
# std      4.978163       3.346513      4.86294    5210.102598    0.497318
# min      0.000000       0.000000      0.00000       0.000000    0.000000
# 25%      1.000000       0.165000      0.00000       0.000000    0.000000
# 50%      2.750000       1.000000      0.00000       5.000000    0.000000
# 75%      7.207500       2.625000      3.00000     395.500000    1.000000
# max     28.000000      28.500000     67.00000  100000.000000    1.000000
#
#               Age
# count  690.000000
# mean    31.576701
# std     11.865617
# min     13.750000
# 25%     22.670000
# 50%     28.580000
# 75%     38.026137
# max     80.250000

# %%
object_columns = crx_data_filtered.select_dtypes(['object'])
object_columns.head()
# Out:
#   Male Married BankCustomer EducationLevel Ethnicity PriorDefault Employed  \
# 0    b       u            g              w         v            t        t
# 1    a       u            g              q         h            t        t
# 2    a       u            g              q         h            t        f
# 3    b       u            g              w         v            t        t
# 4    b       u            g              w         v            t        f
#
#   DriversLicense Citizen ZipCode
# 0              f       g   00202
# 1              f       g   00043
# 2              f       g   00280
# 3              t       g   00100
# 4              f       s   00120

# %%
final_df2 = pd.concat([final_df, object_columns], axis=1)
final_df2.head()
final_df2.describe()
# Out:
#              Debt  YearsEmployed  CreditScore         Income    Approved  \
# count  690.000000     690.000000    690.00000     690.000000  690.000000
# mean     4.758725       2.223406      2.40000    1017.385507    0.444928
# std      4.978163       3.346513      4.86294    5210.102598    0.497318
# min      0.000000       0.000000      0.00000       0.000000    0.000000
# 25%      1.000000       0.165000      0.00000       0.000000    0.000000
# 50%      2.750000       1.000000      0.00000       5.000000    0.000000
# 75%      7.207500       2.625000      3.00000     395.500000    1.000000
# max     28.000000      28.500000     67.00000  100000.000000    1.000000
#
#               Age
# count  690.000000
# mean    31.576701
# std     11.865617
# min     13.750000
# 25%     22.670000
# 50%     28.580000
# 75%     38.026137
# max     80.250000

# %%
#count data for all categorical variables
final_df2.describe(include='object')
# Out:
#        Male Married BankCustomer EducationLevel Ethnicity PriorDefault  \
# count   690     690          690            690       690          690
# unique    3       4            4             15        10            2
# top       b       u            g              c         v            t
# freq    468     519          519            137       399          361
#
#        Employed DriversLicense Citizen ZipCode
# count       690            690     690     690
# unique        2              2       3     171
# top           f              f       g   00000
# freq        395            374     625     132

# %%
#normalized dataframe
normalized_df = final_df2.copy()
normalized_df = normalized_df.select_dtypes(exclude=['object'])
normalized_df = (normalized_df-normalized_df.min())/(normalized_df.max()-normalized_df.min())
normalized_df.head()
# Out:
#        Debt  YearsEmployed  CreditScore   Income  Approved       Age
# 0  0.000000       0.043860     0.014925  0.00000       1.0  0.256842
# 1  0.159286       0.106667     0.089552  0.00560       1.0  0.675489
# 2  0.017857       0.052632     0.000000  0.00824       1.0  0.161654
# 3  0.055000       0.131579     0.074627  0.00003       1.0  0.211729
# 4  0.200893       0.060000     0.000000  0.00000       1.0  0.096541

# %%
#standardized dataframe, use StandardScaler
standardized_df = final_df2.copy()
standardized_df = standardized_df.select_dtypes(exclude=['object'])
standardized_df = (standardized_df-standardized_df.mean())/standardized_df.std()
standardized_df.head()
# Out:
#        Debt  YearsEmployed  CreditScore    Income  Approved       Age
# 0 -0.955920      -0.290872    -0.287892 -0.195272  1.116131 -0.062930
# 1 -0.060007       0.244013     0.740293 -0.087788  1.116131  2.283345
# 2 -0.855481      -0.216167    -0.493529 -0.037117  1.116131 -0.596404
# 3 -0.646569       0.456175     0.534656 -0.194696  1.116131 -0.315761
# 4  0.174015      -0.153415    -0.493529 -0.195272  1.116131 -0.961324

# %%
#standardized_df.groupby(['Approved'])['Approved'].count()
standardized_df.Approved.value_counts()
# Out:
# -0.894654    383
#  1.116131    307
# Name: Approved, dtype: int64

# %%
#sns.histplot(normalized_df["Debt"])

debt_hist = sns.FacetGrid(standardized_df, col='Approved')
debt_hist.map(sns.histplot, 'Debt')

# %%
#sns.histplot(normalized_df["YearsEmployed"])

yearsemployed_hist = sns.FacetGrid(standardized_df, col='Approved')
yearsemployed_hist.map(sns.histplot, 'YearsEmployed')

# %%
#sns.histplot(normalized_df["CreditScore"])

creditscore_hist = sns.FacetGrid(standardized_df, col='Approved')
creditscore_hist.map(sns.histplot, 'CreditScore')

# %%
#sns.histplot(normalized_df["Income"])

income_hist = sns.FacetGrid(standardized_df, col='Approved')
income_hist.map(sns.histplot, 'Income')
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.histplot(standardized_df["Approved"],bins=2)
# Out:
# <AxesSubplot:xlabel='Approved', ylabel='Count'>

# %%
#to list all created dataframes, similar to R
# %whos DataFrame
# Out:
# Variable                 Type         Data/Info
# -----------------------------------------------
# crx_data                 DataFrame        Male    Age    Debt M<...>\n[690 rows x 16 columns]
# crx_data_clean           DataFrame        Male    Age    Debt M<...>\n[690 rows x 16 columns]
# crx_data_filtered        DataFrame        Male    Age    Debt M<...>\n[690 rows x 16 columns]
# crx_data_filtered_copy   DataFrame           Age    Debt  Years<...>n\n[690 rows x 6 columns]
# final_df                 DataFrame           Debt  YearsEmploye<...>n\n[690 rows x 6 columns]
# final_df2                DataFrame           Debt  YearsEmploye<...>\n[690 rows x 16 columns]
# normalized_df            DataFrame             Debt  YearsEmplo<...>n\n[690 rows x 6 columns]
# object_columns           DataFrame        Male Married BankCust<...>\n[690 rows x 10 columns]
# standardized_df          DataFrame             Debt  YearsEmplo<...>n\n[690 rows x 6 columns]
# test_age                 DataFrame           Debt  YearsEmploye<...>   0         0  32.787329
# train_age                DataFrame           Debt  YearsEmploye<...>n\n[678 rows x 6 columns]

# %%
standardized_df.corr()
# Out:
#                    Debt  YearsEmployed  CreditScore    Income  Approved  \
# Debt           1.000000       0.298902     0.271207  0.123121  0.206294
# YearsEmployed  0.298902       1.000000     0.322330  0.051345  0.322475
# CreditScore    0.271207       0.322330     1.000000  0.063692  0.406410
# Income         0.123121       0.051345     0.063692  1.000000  0.175657
# Approved       0.206294       0.322475     0.406410  0.175657  1.000000
# Age            0.202661       0.397802     0.185115  0.018131  0.163310
#
#                     Age
# Debt           0.202661
# YearsEmployed  0.397802
# CreditScore    0.185115
# Income         0.018131
# Approved       0.163310
# Age            1.000000

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Statistical analysis for logistic regression, using all continuous variables
x_approved = standardized_df[['Debt', 'YearsEmployed', 'CreditScore','Income','Age']]
y_approved = final_df2['Approved']

model.fit(x_approved, y_approved)

print(model.coef_)

model_accuracy = model.score(x_approved,y_approved)
print(model_accuracy)
# Out:
# [[0.16421016 0.6945361  1.57068885 1.84022756 0.00705901]]
# 0.7695652173913043

# %%
#Statistical summary for logistic regression
import statsmodels.api as sm

res = sm.Logit(y_approved, x_approved).fit()
print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.497284
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Approved   No. Observations:                  690
# Model:                          Logit   Df Residuals:                      685
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 30 Mar 2022   Pseudo R-squ.:                  0.2762
# Time:                        13:12:24   Log-Likelihood:                -343.13
# converged:                       True   LL-Null:                       -474.08
# Covariance Type:            nonrobust   LLR p-value:                 1.773e-55
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Debt              0.1604      0.101      1.591      0.112      -0.037       0.358
# YearsEmployed     0.6818      0.130      5.254      0.000       0.427       0.936
# CreditScore       1.4824      0.180      8.251      0.000       1.130       1.835
# Income            1.7776      0.408      4.358      0.000       0.978       2.577
# Age              -0.0027      0.104     -0.027      0.979      -0.206       0.200
# =================================================================================

# %%
#Statistical analysis for logistic regression, using 3 predictors
model2 = LogisticRegression()

x_approved2 = standardized_df[['Debt', 'YearsEmployed', 'CreditScore']]
y_approved2 = final_df2['Approved']

model2.fit(x_approved2, y_approved2)

print(model2.coef_)

model2_accuracy = model2.score(x_approved2,y_approved2)
print(model2_accuracy)
# Out:
# [[0.197654   0.67746399 1.69569487]]
# 0.7565217391304347

# %%
#split dataset into train and test, and set the random_state so it maintain the same result

from sklearn.model_selection import train_test_split

data_features = standardized_df[['Debt', 'YearsEmployed', 'CreditScore','Income','Age']]
data_target = final_df2['Approved']

x_train, x_test, y_train, y_test = train_test_split(data_features,
                                                    data_target,
                                                    test_size = 0.2,
                                                    random_state = 808)

# %%
#Logistic regression
model_lr = LogisticRegression()
fitted_model_lr = model_lr.fit(x_train,y_train)
test_predictions_lr = fitted_model_lr.predict(x_test)
accuracy_lr = fitted_model_lr.score(x_test,y_test)
print(fitted_model_lr.coef_)
print(accuracy_lr)
# Out:
# [[0.14363021 0.70905315 1.50100485 1.82423792 0.05006829]]
# 0.7246376811594203

# %%
#logistic regression accuracy score for train data set 
fitted_model_lr.score(x_train,y_train)
# Out:
# 0.7735507246376812

# %%
#Decision tree
from sklearn import tree

model_clf = tree.DecisionTreeClassifier(random_state=101)
fitted_model_clf = model_clf.fit(x_train,y_train)
test_predictions_clf = fitted_model_clf.predict(x_test)
accuracy_clf = fitted_model_clf.score(x_test,y_test)
print(accuracy_clf)
# Out:
# 0.6014492753623188

# %%
#Plot tree from decision tree
plt.figure(figsize=(60,30))
tree.plot_tree(fitted_model_clf,
          filled=True,
          rounded=True,
          class_names=["Approved","Rejected"],
          feature_names=['Debt', 'YearsEmployed', 'CreditScore','Income','Age'],
          fontsize=8)
# Out:
# [Text(2243.8074551569507, 1587.8842105263157, 'CreditScore <= 0.021\ngini = 0.496\nsamples = 552\nvalue = [300, 252]\nclass = Approved'),
#  Text(1567.4983183856502, 1502.0526315789473, 'YearsEmployed <= -0.272\ngini = 0.421\nsamples = 401\nvalue = [280, 121]\nclass = Approved'),
#  Text(727.2141255605382, 1416.221052631579, 'Income <= 0.894\ngini = 0.302\nsamples = 259\nvalue = [211, 48]\nclass = Approved'),
#  Text(697.1872197309417, 1330.3894736842105, 'Debt <= -0.902\ngini = 0.281\nsamples = 254\nvalue = [211, 43]\nclass = Approved'),
#  Text(270.2421524663677, 1244.5578947368422, 'Age <= -0.849\ngini = 0.491\nsamples = 30\nvalue = [17, 13]\nclass = Approved'),
#  Text(150.13452914798205, 1158.7263157894736, 'Income <= -0.191\ngini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = Approved'),
#  Text(90.08071748878923, 1072.8947368421054, 'YearsEmployed <= -0.658\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Approved'),
#  Text(60.053811659192824, 987.0631578947368, 'Age <= -1.109\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(30.026905829596412, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(90.08071748878923, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(120.10762331838565, 987.0631578947368, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Approved'),
#  Text(210.18834080717488, 1072.8947368421054, 'YearsEmployed <= -0.627\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(180.16143497757847, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(240.2152466367713, 987.0631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(390.3497757847534, 1158.7263157894736, 'Debt <= -0.918\ngini = 0.444\nsamples = 15\nvalue = [5, 10]\nclass = Rejected'),
#  Text(360.32286995515693, 1072.8947368421054, 'Debt <= -0.952\ngini = 0.486\nsamples = 12\nvalue = [5, 7]\nclass = Rejected'),
#  Text(300.2690582959641, 987.0631578947368, 'Age <= 0.095\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Rejected'),
#  Text(270.2421524663677, 901.2315789473685, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(330.29596412556054, 901.2315789473685, 'Age <= 0.38\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(300.2690582959641, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(360.32286995515693, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(420.37668161434976, 987.0631578947368, 'Income <= -0.183\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Approved'),
#  Text(390.3497757847534, 901.2315789473685, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Approved'),
#  Text(450.4035874439462, 901.2315789473685, 'Age <= 0.693\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(420.37668161434976, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(480.4304932735426, 815.4, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(420.37668161434976, 1072.8947368421054, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(1124.1322869955156, 1244.5578947368422, 'Income <= -0.119\ngini = 0.232\nsamples = 224\nvalue = [194, 30]\nclass = Approved'),
#  Text(716.8923766816143, 1158.7263157894736, 'Age <= -0.962\ngini = 0.195\nsamples = 192\nvalue = [171, 21]\nclass = Approved'),
#  Text(570.5112107623319, 1072.8947368421054, 'YearsEmployed <= -0.528\ngini = 0.053\nsamples = 37\nvalue = [36, 1]\nclass = Approved'),
#  Text(540.4843049327354, 987.0631578947368, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]\nclass = Approved'),
#  Text(600.5381165919282, 987.0631578947368, 'YearsEmployed <= -0.509\ngini = 0.153\nsamples = 12\nvalue = [11, 1]\nclass = Approved'),
#  Text(570.5112107623319, 901.2315789473685, 'Debt <= 0.3\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(540.4843049327354, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(600.5381165919282, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(630.5650224215246, 901.2315789473685, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = Approved'),
#  Text(863.2735426008968, 1072.8947368421054, 'Age <= -0.947\ngini = 0.225\nsamples = 155\nvalue = [135, 20]\nclass = Approved'),
#  Text(833.2466367713005, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(893.3004484304932, 987.0631578947368, 'YearsEmployed <= -0.658\ngini = 0.216\nsamples = 154\nvalue = [135, 19]\nclass = Approved'),
#  Text(690.6188340807175, 901.2315789473685, 'Income <= -0.166\ngini = 0.067\nsamples = 29\nvalue = [28, 1]\nclass = Approved'),
#  Text(660.5919282511211, 815.4, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = Approved'),
#  Text(720.6457399103139, 815.4, 'CreditScore <= -0.391\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(690.6188340807175, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(750.6726457399103, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1095.982062780269, 901.2315789473685, 'Age <= 1.971\ngini = 0.247\nsamples = 125\nvalue = [107, 18]\nclass = Approved'),
#  Text(1065.9551569506727, 815.4, 'YearsEmployed <= -0.646\ngini = 0.237\nsamples = 124\nvalue = [107, 17]\nclass = Approved'),
#  Text(810.7264573991031, 729.5684210526316, 'Income <= -0.195\ngini = 0.49\nsamples = 7\nvalue = [4, 3]\nclass = Approved'),
#  Text(780.6995515695068, 643.7368421052632, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(840.7533632286995, 643.7368421052632, 'Debt <= -0.818\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Approved'),
#  Text(810.7264573991031, 557.9052631578948, 'Age <= -0.737\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(780.6995515695068, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(840.7533632286995, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(870.780269058296, 557.9052631578948, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Approved'),
#  Text(1321.1838565022422, 729.5684210526316, 'Debt <= 0.082\ngini = 0.211\nsamples = 117\nvalue = [103, 14]\nclass = Approved'),
#  Text(1171.0493273542602, 643.7368421052632, 'Age <= 1.398\ngini = 0.162\nsamples = 90\nvalue = [82, 8]\nclass = Approved'),
#  Text(1050.9417040358744, 557.9052631578948, 'YearsEmployed <= -0.453\ngini = 0.148\nsamples = 87\nvalue = [80, 7]\nclass = Approved'),
#  Text(900.8071748878924, 472.0736842105264, 'Debt <= -0.818\ngini = 0.092\nsamples = 62\nvalue = [59, 3]\nclass = Approved'),
#  Text(840.7533632286995, 386.242105263158, 'YearsEmployed <= -0.621\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = Approved'),
#  Text(810.7264573991031, 300.41052631578964, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = Approved'),
#  Text(870.780269058296, 300.41052631578964, 'Age <= -0.505\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Approved'),
#  Text(840.7533632286995, 214.57894736842104, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(900.8071748878924, 214.57894736842104, 'Debt <= -0.868\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Approved'),
#  Text(870.780269058296, 128.74736842105267, 'Age <= -0.024\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(840.7533632286995, 42.9157894736843, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(900.8071748878924, 42.9157894736843, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(930.8340807174887, 128.74736842105267, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Approved'),
#  Text(960.8609865470852, 386.242105263158, 'Debt <= -0.45\ngini = 0.04\nsamples = 49\nvalue = [48, 1]\nclass = Approved'),
#  Text(930.8340807174887, 300.41052631578964, 'gini = 0.0\nsamples = 35\nvalue = [35, 0]\nclass = Approved'),
#  Text(990.8878923766816, 300.41052631578964, 'Debt <= -0.429\ngini = 0.133\nsamples = 14\nvalue = [13, 1]\nclass = Approved'),
#  Text(960.8609865470852, 214.57894736842104, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1020.914798206278, 214.57894736842104, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Approved'),
#  Text(1201.0762331838564, 472.0736842105264, 'YearsEmployed <= -0.384\ngini = 0.269\nsamples = 25\nvalue = [21, 4]\nclass = Approved'),
#  Text(1171.0493273542602, 386.242105263158, 'Debt <= -0.613\ngini = 0.48\nsamples = 10\nvalue = [6, 4]\nclass = Approved'),
#  Text(1110.9955156950673, 300.41052631578964, 'Debt <= -0.805\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Rejected'),
#  Text(1080.9686098654709, 214.57894736842104, 'Age <= -0.371\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Approved'),
#  Text(1050.9417040358744, 128.74736842105267, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1110.9955156950673, 128.74736842105267, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(1141.0224215246637, 214.57894736842104, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(1231.1031390134528, 300.41052631578964, 'YearsEmployed <= -0.428\ngini = 0.32\nsamples = 5\nvalue = [4, 1]\nclass = Approved'),
#  Text(1201.0762331838564, 214.57894736842104, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Approved'),
#  Text(1261.1300448430493, 214.57894736842104, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1231.1031390134528, 386.242105263158, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Approved'),
#  Text(1291.1569506726457, 557.9052631578948, 'Income <= -0.195\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Approved'),
#  Text(1261.1300448430493, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1321.1838565022422, 472.0736842105264, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(1471.3183856502242, 643.7368421052632, 'Debt <= 0.3\ngini = 0.346\nsamples = 27\nvalue = [21, 6]\nclass = Approved'),
#  Text(1411.2645739910313, 557.9052631578948, 'Age <= 0.127\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Rejected'),
#  Text(1381.237668161435, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1441.2914798206277, 472.0736842105264, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(1531.372197309417, 557.9052631578948, 'Income <= -0.139\ngini = 0.227\nsamples = 23\nvalue = [20, 3]\nclass = Approved'),
#  Text(1501.3452914798206, 472.0736842105264, 'YearsEmployed <= -0.534\ngini = 0.165\nsamples = 22\nvalue = [20, 2]\nclass = Approved'),
#  Text(1471.3183856502242, 386.242105263158, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]\nclass = Approved'),
#  Text(1531.372197309417, 386.242105263158, 'CreditScore <= -0.391\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Approved'),
#  Text(1501.3452914798206, 300.41052631578964, 'Age <= -0.695\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Approved'),
#  Text(1471.3183856502242, 214.57894736842104, 'Age <= -0.825\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Approved'),
#  Text(1441.2914798206277, 128.74736842105267, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(1501.3452914798206, 128.74736842105267, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1531.372197309417, 214.57894736842104, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Approved'),
#  Text(1561.3991031390135, 300.41052631578964, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1561.3991031390135, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1126.0089686098654, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1531.372197309417, 1158.7263157894736, 'YearsEmployed <= -0.328\ngini = 0.404\nsamples = 32\nvalue = [23, 9]\nclass = Approved'),
#  Text(1501.3452914798206, 1072.8947368421054, 'Debt <= 0.052\ngini = 0.358\nsamples = 30\nvalue = [23, 7]\nclass = Approved'),
#  Text(1411.2645739910313, 987.0631578947368, 'CreditScore <= -0.391\ngini = 0.188\nsamples = 19\nvalue = [17, 2]\nclass = Approved'),
#  Text(1381.237668161435, 901.2315789473685, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = Approved'),
#  Text(1441.2914798206277, 901.2315789473685, 'YearsEmployed <= -0.584\ngini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = Approved'),
#  Text(1411.2645739910313, 815.4, 'Age <= -0.463\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(1381.237668161435, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1441.2914798206277, 729.5684210526316, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(1471.3183856502242, 815.4, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Approved'),
#  Text(1591.42600896861, 987.0631578947368, 'Debt <= 1.48\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Approved'),
#  Text(1561.3991031390135, 901.2315789473685, 'YearsEmployed <= -0.658\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Rejected'),
#  Text(1531.372197309417, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1591.42600896861, 815.4, 'Debt <= 0.567\ngini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Rejected'),
#  Text(1561.3991031390135, 729.5684210526316, 'Income <= 0.159\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(1531.372197309417, 643.7368421052632, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1591.42600896861, 643.7368421052632, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1621.4529147982062, 729.5684210526316, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Rejected'),
#  Text(1621.4529147982062, 901.2315789473685, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Approved'),
#  Text(1561.3991031390135, 1072.8947368421054, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(757.2410313901345, 1330.3894736842105, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Rejected'),
#  Text(2407.782511210762, 1416.221052631579, 'Income <= -0.119\ngini = 0.5\nsamples = 142\nvalue = [69, 73]\nclass = Rejected'),
#  Text(2098.1300448430493, 1330.3894736842105, 'Age <= -0.256\ngini = 0.494\nsamples = 117\nvalue = [65, 52]\nclass = Approved'),
#  Text(1771.5874439461884, 1244.5578947368422, 'Debt <= -0.797\ngini = 0.488\nsamples = 52\nvalue = [22, 30]\nclass = Rejected'),
#  Text(1711.5336322869955, 1158.7263157894736, 'Age <= -0.877\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Approved'),
#  Text(1681.506726457399, 1072.8947368421054, 'Debt <= -0.864\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(1651.4798206278026, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1711.5336322869955, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1741.560538116592, 1072.8947368421054, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Approved'),
#  Text(1831.641255605381, 1158.7263157894736, 'YearsEmployed <= -0.104\ngini = 0.458\nsamples = 45\nvalue = [16, 29]\nclass = Rejected'),
#  Text(1801.6143497757848, 1072.8947368421054, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Rejected'),
#  Text(1861.6681614349775, 1072.8947368421054, 'YearsEmployed <= -0.029\ngini = 0.498\nsamples = 34\nvalue = [16, 18]\nclass = Rejected'),
#  Text(1831.641255605381, 987.0631578947368, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Approved'),
#  Text(1891.695067264574, 987.0631578947368, 'Income <= -0.195\ngini = 0.459\nsamples = 28\nvalue = [10, 18]\nclass = Rejected'),
#  Text(1816.627802690583, 901.2315789473685, 'Debt <= -0.629\ngini = 0.219\nsamples = 16\nvalue = [2, 14]\nclass = Rejected'),
#  Text(1756.57399103139, 815.4, 'Age <= -0.793\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(1726.5470852017936, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(1786.6008968609865, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1876.6816143497758, 815.4, 'Debt <= 1.204\ngini = 0.133\nsamples = 14\nvalue = [1, 13]\nclass = Rejected'),
#  Text(1846.6547085201794, 729.5684210526316, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Rejected'),
#  Text(1906.7085201793723, 729.5684210526316, 'Debt <= 1.338\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(1876.6816143497758, 643.7368421052632, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(1936.7354260089685, 643.7368421052632, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(1966.762331838565, 901.2315789473685, 'CreditScore <= -0.391\ngini = 0.444\nsamples = 12\nvalue = [8, 4]\nclass = Approved'),
#  Text(1936.7354260089685, 815.4, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Approved'),
#  Text(1996.7892376681614, 815.4, 'Income <= -0.194\ngini = 0.5\nsamples = 8\nvalue = [4, 4]\nclass = Approved'),
#  Text(1966.762331838565, 729.5684210526316, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(2026.8161434977578, 729.5684210526316, 'Income <= -0.192\ngini = 0.444\nsamples = 6\nvalue = [2, 4]\nclass = Rejected'),
#  Text(1996.7892376681614, 643.7368421052632, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(2056.843049327354, 643.7368421052632, 'YearsEmployed <= 0.014\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Approved'),
#  Text(2026.8161434977578, 557.9052631578948, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(2086.8699551569507, 557.9052631578948, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(2424.6726457399104, 1244.5578947368422, 'Debt <= -0.91\ngini = 0.448\nsamples = 65\nvalue = [43, 22]\nclass = Approved'),
#  Text(2394.6457399103138, 1158.7263157894736, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Rejected'),
#  Text(2454.6995515695066, 1158.7263157894736, 'Debt <= 0.701\ngini = 0.416\nsamples = 61\nvalue = [43, 18]\nclass = Approved'),
#  Text(2342.0986547085204, 1072.8947368421054, 'Age <= 0.805\ngini = 0.366\nsamples = 54\nvalue = [41, 13]\nclass = Approved'),
#  Text(2267.031390134529, 987.0631578947368, 'YearsEmployed <= 0.581\ngini = 0.245\nsamples = 35\nvalue = [30, 5]\nclass = Approved'),
#  Text(2206.9775784753365, 901.2315789473685, 'YearsEmployed <= -0.16\ngini = 0.153\nsamples = 24\nvalue = [22, 2]\nclass = Approved'),
#  Text(2176.95067264574, 815.4, 'YearsEmployed <= -0.185\ngini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = Approved'),
#  Text(2146.9237668161436, 729.5684210526316, 'Age <= 0.418\ngini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Approved'),
#  Text(2116.896860986547, 643.7368421052632, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Approved'),
#  Text(2176.95067264574, 643.7368421052632, 'Debt <= -0.68\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(2146.9237668161436, 557.9052631578948, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2206.9775784753365, 557.9052631578948, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(2206.9775784753365, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2237.0044843049327, 815.4, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = Approved'),
#  Text(2327.085201793722, 901.2315789473685, 'YearsEmployed <= 1.564\ngini = 0.397\nsamples = 11\nvalue = [8, 3]\nclass = Approved'),
#  Text(2297.0582959641256, 815.4, 'Debt <= 0.048\ngini = 0.48\nsamples = 5\nvalue = [2, 3]\nclass = Rejected'),
#  Text(2267.031390134529, 729.5684210526316, 'Age <= 0.373\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Rejected'),
#  Text(2237.0044843049327, 643.7368421052632, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(2297.0582959641256, 643.7368421052632, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(2327.085201793722, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(2357.1121076233185, 815.4, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Approved'),
#  Text(2417.1659192825114, 987.0631578947368, 'Age <= 0.921\ngini = 0.488\nsamples = 19\nvalue = [11, 8]\nclass = Approved'),
#  Text(2387.1390134529147, 901.2315789473685, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(2447.1928251121076, 901.2315789473685, 'CreditScore <= -0.185\ngini = 0.43\nsamples = 16\nvalue = [11, 5]\nclass = Approved'),
#  Text(2417.1659192825114, 815.4, 'Age <= 2.62\ngini = 0.391\nsamples = 15\nvalue = [11, 4]\nclass = Approved'),
#  Text(2387.1390134529147, 729.5684210526316, 'Age <= 1.356\ngini = 0.337\nsamples = 14\nvalue = [11, 3]\nclass = Approved'),
#  Text(2357.1121076233185, 643.7368421052632, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Approved'),
#  Text(2417.1659192825114, 643.7368421052632, 'Age <= 1.57\ngini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = Approved'),
#  Text(2387.1390134529147, 557.9052631578948, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(2447.1928251121076, 557.9052631578948, 'Debt <= -0.768\ngini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = Approved'),
#  Text(2417.1659192825114, 472.0736842105264, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2477.219730941704, 472.0736842105264, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Approved'),
#  Text(2447.1928251121076, 729.5684210526316, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2477.219730941704, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2567.3004484304934, 1072.8947368421054, 'YearsEmployed <= 0.867\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Rejected'),
#  Text(2537.2735426008967, 987.0631578947368, 'Age <= 1.265\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Approved'),
#  Text(2507.2466367713005, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2567.3004484304934, 901.2315789473685, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(2597.3273542600896, 987.0631578947368, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Rejected'),
#  Text(2717.4349775784754, 1330.3894736842105, 'CreditScore <= -0.391\ngini = 0.269\nsamples = 25\nvalue = [4, 21]\nclass = Rejected'),
#  Text(2687.4080717488787, 1244.5578947368422, 'Age <= 0.408\ngini = 0.444\nsamples = 12\nvalue = [4, 8]\nclass = Rejected'),
#  Text(2657.3811659192825, 1158.7263157894736, 'Debt <= 0.551\ngini = 0.444\nsamples = 6\nvalue = [4, 2]\nclass = Approved'),
#  Text(2627.3542600896862, 1072.8947368421054, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Approved'),
#  Text(2687.4080717488787, 1072.8947368421054, 'Debt <= 1.149\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Rejected'),
#  Text(2657.3811659192825, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2717.4349775784754, 987.0631578947368, 'YearsEmployed <= 0.432\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(2687.4080717488787, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(2747.4618834080716, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(2717.4349775784754, 1158.7263157894736, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Rejected'),
#  Text(2747.4618834080716, 1244.5578947368422, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]\nclass = Rejected'),
#  Text(2920.116591928251, 1502.0526315789473, 'YearsEmployed <= -0.602\ngini = 0.23\nsamples = 151\nvalue = [20, 131]\nclass = Rejected'),
#  Text(2807.5156950672645, 1416.221052631579, 'Debt <= -0.613\ngini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = Approved'),
#  Text(2777.4887892376682, 1330.3894736842105, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = Approved'),
#  Text(2837.542600896861, 1330.3894736842105, 'Income <= -0.138\ngini = 0.42\nsamples = 10\nvalue = [3, 7]\nclass = Rejected'),
#  Text(2807.5156950672645, 1244.5578947368422, 'Age <= -0.459\ngini = 0.48\nsamples = 5\nvalue = [3, 2]\nclass = Approved'),
#  Text(2777.4887892376682, 1158.7263157894736, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(2837.542600896861, 1158.7263157894736, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Approved'),
#  Text(2867.5695067264573, 1244.5578947368422, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Rejected'),
#  Text(3032.7174887892374, 1416.221052631579, 'CreditScore <= 0.226\ngini = 0.161\nsamples = 136\nvalue = [12, 124]\nclass = Rejected'),
#  Text(2957.6502242152465, 1330.3894736842105, 'Income <= -0.146\ngini = 0.444\nsamples = 18\nvalue = [6, 12]\nclass = Rejected'),
#  Text(2927.6233183856502, 1244.5578947368422, 'YearsEmployed <= -0.197\ngini = 0.496\nsamples = 11\nvalue = [6, 5]\nclass = Approved'),
#  Text(2897.5964125560536, 1158.7263157894736, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Approved'),
#  Text(2957.6502242152465, 1158.7263157894736, 'Debt <= 0.609\ngini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = Rejected'),
#  Text(2927.6233183856502, 1072.8947368421054, 'Debt <= -0.286\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = Approved'),
#  Text(2897.5964125560536, 987.0631578947368, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Rejected'),
#  Text(2957.6502242152465, 987.0631578947368, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(2987.677130044843, 1072.8947368421054, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Rejected'),
#  Text(2987.677130044843, 1244.5578947368422, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Rejected'),
#  Text(3107.7847533632284, 1330.3894736842105, 'Age <= -1.18\ngini = 0.097\nsamples = 118\nvalue = [6, 112]\nclass = Rejected'),
#  Text(3047.730941704036, 1244.5578947368422, 'Income <= -0.128\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = Approved'),
#  Text(3017.7040358744393, 1158.7263157894736, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = Approved'),
#  Text(3077.7578475336322, 1158.7263157894736, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(3167.8385650224213, 1244.5578947368422, 'Debt <= -0.935\ngini = 0.067\nsamples = 115\nvalue = [4, 111]\nclass = Rejected'),
#  Text(3137.811659192825, 1158.7263157894736, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(3197.865470852018, 1158.7263157894736, 'Age <= -0.762\ngini = 0.051\nsamples = 114\nvalue = [3, 111]\nclass = Rejected'),
#  Text(3137.811659192825, 1072.8947368421054, 'Age <= -0.768\ngini = 0.198\nsamples = 18\nvalue = [2, 16]\nclass = Rejected'),
#  Text(3107.7847533632284, 987.0631578947368, 'Debt <= -0.696\ngini = 0.111\nsamples = 17\nvalue = [1, 16]\nclass = Rejected'),
#  Text(3077.7578475336322, 901.2315789473685, 'Debt <= -0.859\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = Approved'),
#  Text(3047.730941704036, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Rejected'),
#  Text(3107.7847533632284, 815.4, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(3137.811659192825, 901.2315789473685, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = Rejected'),
#  Text(3167.8385650224213, 987.0631578947368, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(3257.919282511211, 1072.8947368421054, 'YearsEmployed <= 2.548\ngini = 0.021\nsamples = 96\nvalue = [1, 95]\nclass = Rejected'),
#  Text(3227.892376681614, 987.0631578947368, 'gini = 0.0\nsamples = 84\nvalue = [0, 84]\nclass = Rejected'),
#  Text(3287.946188340807, 987.0631578947368, 'YearsEmployed <= 3.146\ngini = 0.153\nsamples = 12\nvalue = [1, 11]\nclass = Rejected'),
#  Text(3257.919282511211, 901.2315789473685, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Approved'),
#  Text(3317.9730941704033, 901.2315789473685, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Rejected')]

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

model_rfc = RandomForestClassifier(max_features='sqrt',random_state=201)
fitted_model_rfc = model_rfc.fit(x_train,y_train)
test_predictions_rfc = fitted_model_rfc.predict(x_test)
accuracy_rfc = fitted_model_rfc.score(x_test,y_test)
print(accuracy_rfc)
# Out:
# 0.7971014492753623

# %%
#SVM
from sklearn.svm import SVC

model_svm = SVC(kernel='linear')
fitted_model_svm = model_svm.fit(x_train,y_train)
test_predictions_svm = fitted_model_svm.predict(x_test)
accuracy_svm = fitted_model_svm.score(x_test,y_test)
print(accuracy_svm)
# Out:
# 0.7246376811594203

# %%
#bagging (boostrap aggregation) is basically running one ML model (for example decision tree, SVM, logistical regression, etc) and run it in n number of random sampling, and average the result
from sklearn.model_selection import cross_val_score

#cv = the number of random sampling datasets
clf_for_cross_val = tree.DecisionTreeClassifier(random_state=800)
scores_for_cv = cross_val_score(clf_for_cross_val, data_features, data_target, cv = 5)
print(scores_for_cv)
print(scores_for_cv.mean())
# Out:
# [0.63768116 0.72463768 0.71014493 0.68115942 0.7173913 ]
# 0.6942028985507246

# %%
#bagging, need to explore the concept and what each parameter does
from sklearn.ensemble import BaggingClassifier

#n_estimators is a number of randomly sampled datasets, similar to cv
model_bag = BaggingClassifier(
    base_estimator = tree.DecisionTreeClassifier(),
    n_estimators = 200,
    max_samples = 0.8,
    oob_score = True,
    random_state = 801
)
fitted_model_bag = model_bag.fit(x_train,y_train)
test_predictions_bag = fitted_model_bag.predict(x_test)
accuracy_bag = fitted_model_bag.score(x_test,y_test)
print(accuracy_bag)
print(model_bag.oob_score_)
# Out:
# 0.7753623188405797
# 0.7717391304347826

# %%
#bagging (boostrap aggregation) is basically running one ML model (for example decision tree, SVM, logistical regression, etc) and run it in n number of random sampling, and average the result

from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from time import time

model_bc = BaggingClassifier()

start = time()
cv0 = RepeatedStratifiedKFold(n_splits=5, n_repeats=2, random_state=000)
score_for_cv = cross_val_score(model_bc, data_features, data_target, scoring = 'accuracy', cv=cv0, n_jobs = -1)

print(
    f"Mean Accuracy: {np.mean(score_for_cv):.3f}\nStd: {np.std(score_for_cv):.3f}\nRun time: {(time() - start):.3f}s"
)
# Out:
# Mean Accuracy: 0.758
# Std: 0.038
# Run time: 5.099s

# %%
# %%time

#
res = {}
for i in [10, 25, 50, 100, 200, 800]:
    model_bc1 = BaggingClassifier(n_estimators=i, random_state=901)
    cv1 = RepeatedStratifiedKFold(n_splits=3, n_repeats=2, random_state=901)
    #n_jobs tells the computer on how many processors that it can use to compute, -1 means no restriction, 1 means 1 processor
    res[f'{i}'] = score_for_cv1 = cross_val_score(model_bc1, data_features, data_target, scoring = 'accuracy', cv=cv1, n_jobs = -1)
    #score_for_cv1 = cross_val_score(model_bc1, data_features, data_target, scoring = 'accuracy', cv=cv1, n_jobs = -1)
# Out:
# Wall time: 4.7 s

# %%
#it looks like the object generated from cross_val_score (numpy array) only stores either the last itteration or the highest itteration
print(score_for_cv1)
print(type(score_for_cv1))
print(score_for_cv1.mean())
#200
print(np.mean([0.79130435, 0.7826087 , 0.74347826, 0.73043478, 0.76521739,
       0.74782609]))
#100
print(np.mean([0.8       , 0.79130435, 0.72608696, 0.72608696, 0.76521739,
       0.73043478]))
#50
print(np.mean([0.8       , 0.77391304, 0.7173913 , 0.72608696, 0.7826087 ,
       0.75217391]))
#25
print(np.mean([0.78695652, 0.79565217, 0.73043478, 0.73043478, 0.76521739,
       0.73913043]))
#10
print(np.mean([0.75652174, 0.79565217, 0.73043478, 0.70869565, 0.76956522,
       0.70434783]))
# Out:
# [0.7826087  0.8        0.73478261 0.73043478 0.76956522 0.74782609]
# <class 'numpy.ndarray'>
# 0.7608695652173912
# 0.7601449283333334
# 0.75652174
# 0.7586956516666666
# 0.7579710116666667
# 0.7442028983333334

# %%
plt.style.use(style='seaborn')

plt.figure(1, figsize=(16,8))
boxplot_bag = plt.boxplot(res.values(), labels = res.keys(), showmeans=True)

# %%
print(res)
print(type(res))
list(res.keys())
# Out:
# {'10': array([0.75652174, 0.79565217, 0.73043478, 0.70869565, 0.76956522,
#        0.70434783]), '25': array([0.78695652, 0.79565217, 0.73043478, 0.73043478, 0.76521739,
#        0.73913043]), '50': array([0.8       , 0.77391304, 0.7173913 , 0.72608696, 0.7826087 ,
#        0.75217391]), '100': array([0.8       , 0.79130435, 0.72608696, 0.72608696, 0.76521739,
#        0.73043478]), '200': array([0.79130435, 0.7826087 , 0.74347826, 0.73043478, 0.76521739,
#        0.74782609]), '800': array([0.7826087 , 0.8       , 0.73478261, 0.73043478, 0.76956522,
#        0.74782609])}
# <class 'dict'>
# ['10', '25', '50', '100', '200', '800']

# %%
# %%time

#now we have determined the best n_estimators, let's find out the best max_samples (bootsrap sample), reduced max_samples meaning increase in variance and sometime leads to a better performance, max_samples default is 1 or 100% data
#a better generalization (better bias), go for higher max_samples; for a higher variance, go for lower max_samples
sam = {}
for i in [.1, .25, .5, .75, 1.]:
    model_bc1_bsp = BaggingClassifier(n_estimators=800, max_samples=i, random_state=902)
    cv1_bsp = RepeatedStratifiedKFold(n_splits=3, n_repeats=2, random_state=902)
    #n_jobs tells the computer on how many processors that it can use to compute, -1 means no restriction, 1 means 1 processor
    sam[f'{i*100}'] = score_for_cv1_bsp = cross_val_score(model_bc1_bsp, data_features, data_target, scoring = 'accuracy', cv=cv1_bsp, n_jobs = -1)
    #score_for_cv1 = cross_val_score(model_bc1, data_features, data_target, scoring = 'accuracy', cv=cv1, n_jobs = -1)
# Out:
# Wall time: 17 s

# %%
print(score_for_cv1_bsp)
print(type(score_for_cv1_bsp))
print(score_for_cv1_bsp.mean())
print(sam)
# Out:
# [0.74347826 0.75652174 0.77391304 0.74782609 0.76956522 0.77826087]
# <class 'numpy.ndarray'>
# 0.7615942028985508
# {'10.0': array([0.75217391, 0.82608696, 0.7826087 , 0.7826087 , 0.76521739,
#        0.7826087 ]), '25.0': array([0.75217391, 0.82608696, 0.79130435, 0.8173913 , 0.76956522,
#        0.79565217]), '50.0': array([0.75652174, 0.80869565, 0.8       , 0.8       , 0.76521739,
#        0.77391304]), '75.0': array([0.74782609, 0.7826087 , 0.79130435, 0.77826087, 0.76521739,
#        0.77391304]), '100.0': array([0.74347826, 0.75652174, 0.77391304, 0.74782609, 0.76956522,
#        0.77826087])}

# %%
plt.figure(1, figsize=(16,8))
boxplot_bag_bsp = plt.boxplot(sam.values(), labels = sam.keys(), showmeans=True)

# %%
#extra: create a function that can return any accuracy score for any classifier
def get_score(model, x_train, x_test, y_train, y_test):
    model.fit(x_train, y_train)
    return model.score(x_test, y_test)

# %% [markdown]
# Passive agressive notes:
# 1. On-line algorithm: Use for massive stream of data and want to learn on the fly. Example: twitter data. To big to store, so this alg grab a sample of the data, update classifier, and throw away said example.
# 2. If prediction is negative, that means it is wrong, then penalized. If the prediction is too close to the w, that means the prediction is correct, however we still need to penalize it since it is too close. If the prediction is >= 1, then the prediction is correct and no need to change
# 3. Penalized by how far off from 1; L (loss or penalty) = max (0,1 - y(d t w))
# 4. When this alg gets a new example and couldn't classify it perfectly (smaller than +1, < 1), it moves the weight factor (represented by the line) just enough to make the new dot product exactly +1.
#     This is why its being called aggressive, because it can changes everytime the new sample couldn't be classified perfectly (= +1). If the product (prediction) is okay (> +1), then the alg will not do anything (passive).
# 5. The w line is always perpendicular to the prediction/decision line
# 6. A good use case for this alg is detecting fake news on a social media like Twitter

# %%
#Passive Aggresive Classifier
from sklearn.linear_model import PassiveAggressiveClassifier

model_pac = PassiveAggressiveClassifier(C=0.5,random_state=301)
fitted_model_pac = model_pac.fit(x_train,y_train)
test_predictions_pac = fitted_model_pac.predict(x_test)
accuracy_pac = fitted_model_pac.score(x_test,y_test)
print(accuracy_pac)
print(fitted_model_pac.coef_)
# Out:
# 0.6521739130434783
# [[-1.0355466   1.85242245  1.54376879  1.50600173 -0.41428985]]

# %%
#Radius Neighbors Classifier
from sklearn.neighbors import RadiusNeighborsClassifier

model_rn = RadiusNeighborsClassifier(radius=9.4)
fitted_model_rn = model_rn.fit(x_train,y_train)
test_predictions_rn = fitted_model_rn.predict(x_test)
accuracy_rn = fitted_model_rn.score(x_test,y_test)
print(accuracy_rn)
# Out:
# 0.6086956521739131

# %%
# %%time

#
res = {}
for i in [10, 25, 50, 100, 200, 800]:
    model_bc1 = BaggingClassifier(n_estimators=i, random_state=901)
    cv1 = RepeatedStratifiedKFold(n_splits=3, n_repeats=2, random_state=901)
    #n_jobs tells the computer on how many processors that it can use to compute, -1 means no restriction, 1 means 1 processor
    res[f'{i}'] = score_for_cv1 = cross_val_score(model_bc1, data_features, data_target, scoring = 'accuracy', cv=cv1, n_jobs = -1)
    #score_for_cv1 = cross_val_score(model_bc1, data_features, data_target, scoring = 'accuracy', cv=cv1, n_jobs = -1)
